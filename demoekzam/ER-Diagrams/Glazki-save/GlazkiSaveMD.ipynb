-- %% [markdown]
-- # [GlazkiSaveMD]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [GlazkiSaveMD]    Script Date: 10.10.2022 11:06:00 ******/
CREATE DATABASE [GlazkiSaveMD]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'GlazkiSaveMD', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\GlazkiSaveMD.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 10%)
 LOG ON 
( NAME = N'GlazkiSaveMD_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\GlazkiSaveMD_log.ldf' , SIZE = 1024KB , MAXSIZE = 2048GB , FILEGROWTH = 10%)
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [GlazkiSaveMD] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [GlazkiSaveMD].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [GlazkiSaveMD] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET ARITHABORT OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [GlazkiSaveMD] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [GlazkiSaveMD] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET  DISABLE_BROKER 
GO
ALTER DATABASE [GlazkiSaveMD] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [GlazkiSaveMD] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [GlazkiSaveMD] SET  MULTI_USER 
GO
ALTER DATABASE [GlazkiSaveMD] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [GlazkiSaveMD] SET DB_CHAINING OFF 
GO
ALTER DATABASE [GlazkiSaveMD] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [GlazkiSaveMD] SET TARGET_RECOVERY_TIME = 0 SECONDS 
GO
ALTER DATABASE [GlazkiSaveMD] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [GlazkiSaveMD] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [GlazkiSaveMD] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Agents]

-- %%
USE [GlazkiSaveMD]
GO

-- %%
/****** Object:  Table [dbo].[Agents]    Script Date: 10.10.2022 11:06:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agents](
	[AgentID] [int] NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[AgentTypeID] [int] NOT NULL,
	[Priotiry] [nvarchar](50) NOT NULL,
	[LogoID] [int] NOT NULL,
	[Adress] [nvarchar](50) NOT NULL,
	[INN] [nchar](50) NOT NULL,
	[KPP] [nvarchar](50) NOT NULL,
	[DirectorName] [nvarchar](50) NOT NULL,
	[Telephone] [nvarchar](50) NOT NULL,
	[CompEmail] [nvarchar](50) NOT NULL,
	[Discount] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AgentTypes]

-- %%
/****** Object:  Table [dbo].[AgentTypes]    Script Date: 10.10.2022 11:06:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AgentTypes](
	[TypeID] [int] NOT NULL,
	[Name] [nvarchar](50) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Logos]

-- %%
/****** Object:  Table [dbo].[Logos]    Script Date: 10.10.2022 11:06:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Logos](
	[LogoID] [int] NOT NULL,
	[PreviewLogo] [nvarchar](50) NOT NULL,
	[LogoPath] [nvarchar](150) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Orders]

-- %%
/****** Object:  Table [dbo].[Orders]    Script Date: 10.10.2022 11:06:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Orders](
	[OrderID] [int] NOT NULL,
	[OrderName] [nchar](50) NOT NULL,
	[Amount] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RealizeHistory]

-- %%
/****** Object:  Table [dbo].[RealizeHistory]    Script Date: 10.10.2022 11:06:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RealizeHistory](
	[OrderID] [int] NOT NULL,
	[AgentID] [int] NOT NULL,
	[Date] [date] NOT NULL,
	[Amount] [nvarchar](50) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [GlazkiSaveMD]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [GlazkiSaveMD] SET  READ_WRITE 
GO
